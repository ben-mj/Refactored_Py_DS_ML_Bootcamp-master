# %% [markdown]
# # How to use git

# %% [markdown]
# 1. Add new Branch

# %%
# git branch -m <new_branch_name>

# %% [markdown]
# 2. change to new branch

# %%
# git checkout <new branch>

# %% [markdown]
# 3. Check git status >> ไว้ดูว่า สถานะตอนนี้เป็นไง

# %%
# git status

# %% [markdown]
# 4. check ว่ามี branch อะไรบ้าง
#
#
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>

# %%
# git branch

# %% [markdown]
# 5. Mykey
#
# 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

# %% [markdown]
# 6. add file that we update

# %%
# git add . / git add -A

# %% [markdown]
# 7. commit what we change + comment

# %%
# git commit -m 'commit message'

# %% [markdown]
# 8. push กลับไปที่ branch ของเรา

# %%
# git push origin <feature_branch>
